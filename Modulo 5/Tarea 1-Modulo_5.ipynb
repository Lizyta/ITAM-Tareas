# %% [markdown]
# # Tarea 1

# %% [markdown]
# Red Neuronal de Regresión con $m=3, L_1=4, L_2=2, L_3=2, L_4=1$, donde $t_n \in R$

# %% [markdown]
# ![grafica1.PNG](attachment:grafica1.PNG)

# %% [markdown]
# ---
# ***
# 1. El número total de pesos esta dado por :
#
# $ w = (x*L_1) + (L_1*L_2) + (L_2*L_3) + (L_3*L_4) $
#
# $ w = (3*4) + (4*2) + (2*2) + (2*1) = 26 $
#
# Los pesos del sesgo son:
#
# $w= ( x_{0} * L_1) + L_2 + L_3 + L_4$
#
# $w = (1*4)+ 2 + 2 + 1 = 9$

# %% [markdown]
# ---
# ***
# 2. Descoponer explicitamente $\hat{y}_n$ en terminos de $w^{(1)}, w^{(2)}, w^{(3)},...$

# %% [markdown]
# Sea
#
# $\hat{y}_n = a^4$
#
# ***
# Se sustituye $a^4$ en terminos de la trasformación de $f^{(4)}$.
#
#
# $\hat{y}_n  = {f}^{(4)} \left({w_1}^{(4)} {a_1}^{(3)} + {w_2}^{(4)} {a_2}^{(3)} + {w_0}^{(4)} {a_0}^{(3)}\right)$
#
# ***
# Se ponen las $a_i^{(3)}$ en terminos de $f^{(3)} ({z_i}^{(3)}) $  .
#
#
# $\hat{y}_n ={f}^{(4)} \left( {w_1}^{(4)} {f}^{(3)} ({z_1}^{(3)})+ {w_2}^{(4)} {f}^{(3)} ({z_2}^{(3)}) + {w_0}^{(4)} {a_0}^{(3)}\right) $
#
# ***
# Se sustituyen $z_i^{(3)}$ en terminos de ${w_{ij}}^{(3)} $ y $a_i^{(2)}$.
#
#
# $\hat{y}_n = {f}^{(4)} \left({w_1}^{(4)} {f}^{(3)} \left({w_{11}}^{(3)} {a_1}^{(2)}+{w_{12}}^{(3)} {a_2}^{(2)} + {w_{10}}^{(3)} {a_0}^{(2)} \right)+ {w_2}^{(4)} {f}^{(3)} \left({w_{21}}^{(3)} {a_1}^{(2)}+{w_{22}}^{(3)} {a_2}^{(2)} + {w_{20}}^{(3)} {a_0}^{(2)} \right) + {w_0}^{(4)} {a_0}^{(3)}\right)$
#
# ***
# Se ponen las $a_i^{(2)}$ en terminos de $f^{(2)} ({z_i}^{(2)})$.
#
#
# $\hat{y}_n = {f}^{(4)} \left({w_1}^{(4)} {f}^{(3)} \left({w_{11}}^{(3)} {f}^{(2)} ({z_1}^{(2)})+{w_{12}}^{(3)} {f}^{(2)} ({z_2}^{(2)} )+ {w_{10}}^{(3)} {a_0}^{(2)}\right)+ {w_2}^{(4)} {f}^{(3)} \left({w_{21}}^{(3)} {f}^{(2)} ({z_1}^{(2)})+{w_{22}}^{(3)} {f}^{(2)} ({z_2}^{(2)}) + {w_{20}}^{(3)} {a_0}^{(2)}\right)  + {w_0}^{(4)} {a_0}^{(3)}\right)$
#
# ***
# Se sustituyen $z_i^{(2)}$ en terminos de ${w_{ij}}^{(2)} $ y $a_i^{(1)}$.
#
#
# $\hat{y}_n = {f}^{(4)} \left({w_1}^{(4)} {f}^{(3)} \left({w_{11}}^{(3)} {f}^{(2)} \left({w_{11}}^{(2)} {a_1}^{(1)}+{w_{12}}^{(2)} {a_2}^{(1)} + {w_{13}}^{(2)} {a_3}^{(1)} + {w_{14}}^{(2)} {a_4}^{(1)} + {w_{10}}^{(2)} {a_0}^{(1)}\right) + {w_{12}}^{(3)} {f}^{(2)} \left({w_{21}}^{(2)} {a_1}^{(1)}+{w_{22}}^{(2)} {a_2}^{(1)} + {w_{23}}^{(2)} {a_3}^{(1)} + {w_{24}}^{(2)} {a_4}^{(1)} + {w_{20}}^{(2)} {a_0}^{(1)}\right) + {w_{10}}^{(3)} {a_0}^{(2)}\right)+ {w_2}^{(4)} {f}^{(3)} \left({w_{21}}^{(3)} {f}^{(2)} \left({w_{11}}^{(2)} {a_1}^{(1)}+{w_{12}}^{(2)} {a_2}^{(1)} + {w_{13}}^{(2)} {a_3}^{(1)} + {w_{14}}^{(2)} {a_4}^{(1)} + {w_{10}}^{(2)} {a_0}^{(1)}\right) +{w_{22}}^{(3)} {f}^{(2)} \left({w_{21}}^{(2)} {a_1}^{(1)}+{w_{22}}^{(2)} {a_2}^{(1)} + {w_{23}}^{(2)} {a_3}^{(1)} + {w_{24}}^{(2)} {a_4}^{(1)} + {w_{20}}^{(2)} {a_0}^{(1)}\right) + {w_{20}}^{(3)} {a_0}^{(2)}\right) + {w_0}^{(4)} {a_0}^{(3)}\right)$
#
# ***
# Se ponen las $a_i^{(1)}$ en terminos de $f^{(1)} ({z_i}^{(1)})$.
#
#
# $\hat{y}_n = {f}^{(4)} \left({w_1}^{(4)} {f}^{(3)} \left({w_{11}}^{(3)} {f}^{(2)} \left({w_{11}}^{(2)} {f}^{(1)} ({z_1}^{(1)})+{w_{12}}^{(2)} {f}^{(1)} ({z_2}^{(1)}) + {w_{13}}^{(2)} {f}^{(1)} ({z_3}^{(1)}) + {w_{14}}^{(2)} {f}^{(1)} ({z_4}^{(1)}) + {w_{10}}^{(2)} {a_0}^{(1)}\right) + {w_{12}}^{(3)} {f}^{(2)} \left({w_{21}}^{(2)} {f}^{(1)} ({z_1}^{(1)})+{w_{22}}^{(2)} {f}^{(1)} ({z_2}^{(1)}) + {w_{23}}^{(2)} {f}^{(1)} ({z_3}^{(1)}) + {w_{24}}^{(2)} {f}^{(1)} ({z_4}^{(1)}) + {w_{20}}^{(2)} {a_0}^{(1)}\right) + {w_{10}}^{(3)} {a_0}^{(2)}\right)+ {w_2}^{(4)} {f}^{(3)} \left({w_{21}}^{(3)} {f}^{(2)} \left({w_{11}}^{(2)} {f}^{(1)} ({z_1}^{(1)}) +{w_{12}}^{(2)} {f}^{(1)} ({z_2}^{(1)}) + {w_{13}}^{(2)} {f}^{(1)} ({z_3}^{(1)}) + {w_{14}}^{(2)} {f}^{(1)} ({z_4}^{(1)}) + {w_{10}}^{(2)} {a_0}^{(1)}\right) +{w_{22}}^{(3)} {f}^{(2)} \left({w_{21}}^{(2)} {f}^{(1)} ({z_1}^{(1)})+{w_{22}}^{(2)} {f}^{(1)} ({z_2}^{(1)}) + {w_{23}}^{(2)} {f}^{(1)} ({z_3}^{(1)}) + {w_{24}}^{(2)} {f}^{(1)} ({z_4}^{(1)}) + {w_{20}}^{(2)} {a_0}^{(1)}\right) + {w_{20}}^{(3)} {a_0}^{(2)}\right) + {w_0}^{(4)} {a_0}^{(3)}\right)$
#
# ***
# Se sustituyen $z_i^{(1)}$ en terminos de ${w_{ij}}^{(1)} $ y $x_i$.
#
#
# $\hat{y}_n = {f}^{(4)} \left({w_1}^{(4)} {f}^{(3)} \left({w_{11}}^{(3)} {f}^{(2)} \left({w_{11}}^{(2)} {f}^{(1)} \left({w_{11}}^{(1)} {x_1} +{w_{12}}^{(1)} {x_2} + {w_{13}}^{(1)} {x_3}+ {w_{10}}^{(1)} {x_0}\right)+{w_{12}}^{(2)} {f}^{(1)} \left({w_{21}}^{(1)} {x_1} +{w_{22}}^{(1)} {x_2} + {w_{23}}^{(1)} {x_3}+ {w_{20}}^{(1)} {x_0}\right) + {w_{13}}^{(2)} {f}^{(1)} \left({w_{31}}^{(1)} {x_1} +{w_{32}}^{(1)} {x_2} + {w_{33}}^{(1)} {x_3}+ {w_{30}}^{(1)} {x_0}\right) + {w_{14}}^{(2)} {f}^{(1)} \left({w_{41}}^{(1)} {x_1} +{w_{42}}^{(1)} {x_2} + {w_{43}}^{(1)} {x_3}+ {w_{40}}^{(1)} {x_0}\right) + {w_{10}}^{(2)} {a_0}^{(1)}\right) + {w_{12}}^{(3)} {f}^{(2)} \left({w_{21}}^{(2)} {f}^{(1)} \left({w_{11}}^{(1)} {x_1} +{w_{12}}^{(1)} {x_2} + {w_{13}}^{(1)} {x_3}+ {w_{10}}^{(1)} {x_0}\right)+{w_{22}}^{(2)} {f}^{(1)} \left({w_{21}}^{(1)} {x_1} +{w_{22}}^{(1)} {x_2} + {w_{23}}^{(1)} {x_3}+ {w_{20}}^{(1)} {x_0}\right) + {w_{23}}^{(2)} {f}^{(1)} \left({w_{31}}^{(1)} {x_1} +{w_{32}}^{(1)} {x_2} + {w_{33}}^{(1)} {x_3}+ {w_{30}}^{(1)} {x_0}\right) + {w_{24}}^{(2)} {f}^{(1)} \left({w_{41}}^{(1)} {x_1} +{w_{42}}^{(1)} {x_2} + {w_{43}}^{(1)} {x_3}+ {w_{40}}^{(1)} {x_0}\right) + {w_{20}}^{(2)} {a_0}^{(1)}\right) + {w_{10}}^{(3)} {a_0}^{(2)}\right)+ {w_2}^{(4)} {f}^{(3)} \left({w_{21}}^{(3)} {f}^{(2)} \left({w_{11}}^{(2)} {f}^{(1)} \left({w_{11}}^{(1)} {x_1} +{w_{12}}^{(1)} {x_2} + {w_{13}}^{(1)} {x_3}+ {w_{10}}^{(1)} {x_0}\right) +{w_{12}}^{(2)} {f}^{(1)} \left({w_{21}}^{(1)} {x_1} +{w_{22}}^{(1)} {x_2} + {w_{23}}^{(1)} {x_3}+ {w_{20}}^{(1)} {x_0}\right) + {w_{13}}^{(2)} {f}^{(1)} \left({w_{31}}^{(1)} {x_1} +{w_{32}}^{(1)} {x_2} + {w_{33}}^{(1)} {x_3}+ {w_{30}}^{(1)} {x_0}\right) + {w_{14}}^{(2)} {f}^{(1)} \left({w_{41}}^{(1)} {x_1} +{w_{42}}^{(1)} {x_2} + {w_{43}}^{(1)} {x_3}+ {w_{40}}^{(1)} {x_0}\right) + {w_{10}}^{(2)} {a_0}^{(1)}\right) +{w_{22}}^{(3)} {f}^{(2)} \left({w_{21}}^{(2)} {f}^{(1)} \left({w_{11}}^{(1)} {x_1} +{w_{12}}^{(1)} {x_2} + {w_{13}}^{(1)} {x_3}+ {w_{10}}^{(1)} {x_0}\right)+{w_{22}}^{(2)} {f}^{(1)} \left({w_{21}}^{(1)} {x_1} +{w_{22}}^{(1)} {x_2} + {w_{23}}^{(1)} {x_3}+ {w_{20}}^{(1)} {x_0}\right) + {w_{23}}^{(2)} {f}^{(1)} \left({w_{31}}^{(1)} {x_1} +{w_{32}}^{(1)} {x_2} + {w_{33}}^{(1)} {x_3}+ {w_{30}}^{(1)} {x_0}\right) + {w_{24}}^{(2)} {f}^{(1)} \left({w_{41}}^{(1)} {x_1} +{w_{42}}^{(1)} {x_2} + {w_{43}}^{(1)} {x_3}+ {w_{40}}^{(1)} {x_0}\right) + {w_{20}}^{(2)} {a_0}^{(1)}\right) + {w_{20}}^{(3)} {a_0}^{(2)}\right) + {w_0}^{(4)} {a_0}^{(3)}\right)$
